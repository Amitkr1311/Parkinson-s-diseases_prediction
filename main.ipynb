# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
from plotly.offline import iplot
import plotly as py

# %%
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',25)
pd.set_option('display.width',200)

# %%
df = pd.read_csv('parkinsons.data')
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784          0.000070   0.00370   0.00554     0.01109       0.04374             0.426       0.02182       0.03130   0.02971
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968          0.000080   0.00465   0.00696     0.01394       0.06134             0.626       0.03134       0.04518   0.04368
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050          0.000090   0.00544   0.00781     0.01633       0.05233             0.482       0.02757       0.03858   0.03590
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997          0.000090   0.00502   0.00698     0.01505       0.05492             0.517       0.02924       0.04005   0.03772
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
# find null values
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
for i in df.columns:
    print("**************************************", i , 
         "*********************************************")
    print()
    print(set(df[i].tolist()))
    print()
# Out:
# ************************************** name *********************************************
#
# ...

# %%
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# finding the distribution of the dataset

def distplots(col):
    sns.distplot(df[col],kde = True)
    plt.show()

for i in list(df.columns) [1:]:
    distplots(i)

# %%
# finding the outlier, 
# means either it is very higher or very lower then most of the data value

def boxplots(col):
    sns.boxplot(x=df[col])  # Use x= to make it horizontal
    plt.title(f'Boxplot of {col}')
    plt.show()

for i in list(df.columns)[1:]:
    boxplots(i)

# %%
df = df.drop('name', axis = 1)

# %%
# find correlation

plt.figure(figsize=(20,20))
corr = df.corr()
sns.heatmap(corr, annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %%
x = df.drop('status', axis = 1)
y = df['status']

# %%
x.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# 0      119.992       157.302        74.997         0.00784           0.00007   0.00370   0.00554     0.01109       0.04374             0.426       0.02182       0.03130   0.02971      0.06545
# 1      122.400       148.650       113.819         0.00968           0.00008   0.00465   0.00696     0.01394       0.06134             0.626       0.03134       0.04518   0.04368      0.09403
# 2      116.682       131.111       111.555         0.01050           0.00009   0.00544   0.00781     0.01633       0.05233             0.482       0.02757       0.03858   0.03590      0.08270
# 3      116.676       137.871       111.366         0.00997           0.00009   0.00502   0.00698     0.01505       0.05492             0.517       0.02924       0.04005   0.03772      0.08771
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=1)

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
x_train_ros, y_train_ros = ros.fit_resample(x_train, y_train)

# %%
x_train_ros.value_counts()
y_train_ros.value_counts()
# Out:
# status
# 0    118
# 1    118
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler((-1, 1))
x_train_scaled = scaler.fit_transform(x_train_ros)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95)
x_train_pca = pca.fit_transform(x_train_scaled)
x_test_pca = pca.transform(x_test_scaled)

# %%
x_train_pca = x_train_scaled
x_test_pca = x_test_scaled

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(criterion='entropy', random_state=1)
model.fit(x_train_pca, y_train_ros)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=1)

# %%
y_pred = model.predict(x_test_pca)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8974358974358975
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        10
#            1       0.93      0.93      0.93        29
#
#     accuracy                           0.90        39
#    macro avg       0.87      0.87      0.87        39
# weighted avg       0.90      0.90      0.90        39

# %%
# from imblearn.over_sampling import RandomOverSampler # or we can use SMOTE synthetic minority over-sampling technique
# ros = RandomOverSampler()
# x_ros, y_ros = ros.fit_resample(x,y)
# print("Before SMOTE:")
# print(y.value_counts())
# print("\nAfter SMOTE:")
# print(y_ros.value_counts())

# %%
# from imblearn.over_sampling import SMOTE

# # Initialize SMOTE
# smote = SMOTE(sampling_strategy='auto', random_state=42)

# # Fit and resample the data
# X_resampled, y_resampled = smote.fit_resample(x, y)

# # Check the new class distribution
# print("Before SMOTE:")
# print(y.value_counts())
# print("\nAfter SMOTE:")
# print(y_resampled.value_counts())

# %%
# The MinMaxScaler is a feature scaling technique used in data preprocessing, 
# and it's very useful in machine learning when your features have different units 
# or scales (for example, one feature is in range 0-1000, and another is in range 0-1). 
# The MinMaxScaler normalizes the data by transforming it into a fixed range, 
# typically [0, 1], or any other range you specify (e.g., [-1, 1]).

# %%
# scaler = MinMaxScaler((-1, 1))
# x = scaler.fit_transform(x_ros)
# y = y_ros

# %%
# df_scaled = pd.DataFrame(x,y)
# df_scaled

# %%
# x.shape

# %%
# from sklearn.decomposition import PCA

# %%
# pca = PCA(0.95)
# x_pca = pca.fit_transform(x)
# print(x.shape)
# print(x_pca.shape)

# %%
# pd.DataFrame(x_pca)

# %%
# print(y)

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.2, random_state=1)

# %%
# from imblearn.over_sampling import RandomOverSampler # or we can use SMOTE synthetic minority over-sampling technique
# ros = RandomOverSampler()
# x_ros, y_ros = ros.fit_resample(x, y)
# print("Before:")
# print(y.value_counts())
# print("\nAfter:")
# print(y_ros.value_counts())

# %%
# # feature Scaling
# from sklearn.preprocessing import MinMaxScaler

# %%
# scaler = MinMaxScaler((-1, 1))
# x = scaler.fit_transform(x_ros)
# y = y_ros

# %%
# df_scaled = pd.DataFrame(x,y)
# df_scaled

# %%
# x.shape

# %%
# from sklearn.decomposition import PCA

# %%
# pca = PCA(0.95)
# x_pca = pca.fit_transform(x)
# print(x.shape)
# print(x_pca.shape)

# %%
# pd.DataFrame(x_pca)

# %%
# Model Building

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
list_met = []
list_acuuracy = []

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
classifier1 =  LogisticRegression(C=0.5, max_iter = 1000, solver = 'liblinear')
LR = classifier1.fit(x_train_pca, y_train_ros)
# Prediction
y_pred1 = classifier1.predict(x_test_pca)
# Accuracy
accuracy_LR = accuracy_score(y_test, y_pred1)

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
classifier2 = DecisionTreeClassifier(random_state = 1)
DT = classifier2.fit(x_train_pca, y_train_ros)
# Pediction
y_pred2 = classifier2.predict(x_test_pca);
# Accuracy
accuracy_DT = accuracy_score(y_test, y_pred2)

# %%
# random forest classifier
# criteria = gini
from sklearn.ensemble import RandomForestClassifier
classifier3 = RandomForestClassifier(random_state=14)

RFI = classifier3.fit(x_train_pca, y_train_ros)
# Pediction
y_pred3 = classifier3.predict(x_test_pca);
# Accuracy
accuracy_RFI = accuracy_score(y_test, y_pred3)

# %%
# criteria = entropy
from sklearn.ensemble import RandomForestClassifier
classifier4 = RandomForestClassifier(criterion = 'entropy', random_state = 1)
RFE = classifier4.fit(x_train_pca, y_train_ros)
# Pediction
y_pred4 = classifier4.predict(x_test_pca);
# Accuracy
accuracy_RFE = accuracy_score(y_test, y_pred4)

# %%
# Support vector machine
from sklearn.svm import SVC
model_svm = SVC()
SVM = model_svm.fit(x_train_pca, y_train_ros)
# Prediction
y_pred5 = model_svm.predict(x_test_pca);
# accuracy
accuracy_SVC = accuracy_score(y_test, y_pred5)

# %%
# KNN Model
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier()
KNN = model_knn.fit(x_train_pca, y_train_ros)
# Prediction
y_pred6 = model_knn.predict(x_test_pca);
# accuracy
accuracy_KNN = accuracy_score(y_test, y_pred6)

# %%
# naive-bayes
from sklearn.naive_bayes import GaussianNB
model_gnb = GaussianNB()
GNB = model_gnb.fit(x_train_pca, y_train_ros)
# Prediction
y_pred7 = model_gnb.predict(x_test_pca);
# accuracy
accuracy_gnb = accuracy_score(y_test, y_pred7)

# %%
# model 8
from sklearn.naive_bayes import BernoulliNB
model_bnb =  BernoulliNB()
BNB = model_bnb.fit(x_train_pca, y_train_ros)
# prediction
y_pred8 = model_bnb.predict(x_test_pca)
# accuracy
accuracy_bnb = accuracy_score(y_test, y_pred8)

# %%
# Combining all the above model by Voting Classifier model
from sklearn.ensemble import VotingClassifier
evc = VotingClassifier(estimators = [('LR', LR), ('DT',DT), ('RFI', RFI),
                                     ('RFE', RFE),('SVM',SVM), ('KNN',KNN),
                                     ('GNB',GNB), ('BNB', BNB)], voting = 'hard',
                                      flatten_transform=True)
model_evc = evc.fit(x_train_pca, y_train_ros)
# prediction
pred_evc = evc.predict(x_test_pca)
# accuracy
accuracy_evc = accuracy_score(y_test, pred_evc)

list1 = ["Logistic Regression", "Decision Tree", "random Forest Gini", "Random Forest Entropy",
        "Support Vector", "K Nearest Neighbour","GuassianNB", "BernoulliNB", "Voting Classifier"]

list2 = [accuracy_LR, accuracy_DT, accuracy_RFI, accuracy_RFE, accuracy_SVC, accuracy_KNN, 
        accuracy_gnb, accuracy_bnb, accuracy_evc]

list3 = [classifier1, classifier2, classifier3, classifier4, model_svm, model_knn,
         model_gnb, model_bnb, model_evc]

df_accuracy = pd.DataFrame({'Method Used' :list1, "Accuracy" :list2})
print(df_accuracy)

charts = sns.barplot(x = 'Method Used', y = 'Accuracy', data = df_accuracy, palette = 'bright')
charts.set_xticklabels(charts.get_xticklabels(), rotation = 90)
print(charts)
# Out:
#              Method Used  Accuracy
# 0    Logistic Regression  0.769231
# 1          Decision Tree  0.871795
# 2     random Forest Gini  0.923077
# 3  Random Forest Entropy  0.897436
# 4         Support Vector  0.820513
# 5    K Nearest Neighbour  0.923077
# 6             GuassianNB  0.641026
# 7            BernoulliNB  0.666667
# 8      Voting Classifier  0.820513
# Axes(0.125,0.11;0.775x0.77)

# %%
from xgboost import XGBClassifier

# %%
model_xgb =  XGBClassifier()
model_xgb.fit(x_train, y_train)
# prediction
xgb_pred = model_xgb.predict(x_test)
# Accuracy
xgb_accuracy = accuracy_score(y_test, xgb_pred)

# %%
xgb_accuracy
# Out:
# 0.9230769230769231

# %%
# Confusion Matrics and Classification report for RFE
#🔹 Predictions
y_train_pred = classifier3.predict(x_train_pca)
y_test_pred = classifier3.predict(x_test_pca)

# 📘 Training Results
print("📘 Training Data")
print("Confusion Matrix:")
print(confusion_matrix(y_train_ros, y_train_pred))
print("\nClassification Report:")
print(classification_report(y_train_ros, y_train_pred))

# 📙 Testing Results
print("\n📙 Testing Data")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# 📘 Training Data
# Confusion Matrix:
# [[118   0]
#  [  0 118]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       118
#            1       1.00      1.00      1.00       118
#
#     accuracy                           1.00       236
#    macro avg       1.00      1.00      1.00       236
# weighted avg       1.00      1.00      1.00       236
#
#
# 📙 Testing Data
# Confusion Matrix:
# [[ 8  2]
#  [ 1 28]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.91      0.88      0.90        39
# weighted avg       0.92      0.92      0.92        39

# %%
# Confussion MAtrics and Classification Report for KNN
# 🔹 Predictions
y_train_pred_knn = model_knn.predict(x_train_pca)
y_test_pred_knn = model_knn.predict(x_test_pca)  # same as y_pred6

# 📘 Training Results
print("📘 Training Data - KNN")
print("Confusion Matrix:")
print(confusion_matrix(y_train_ros, y_train_pred_knn))
print("\nClassification Report:")
print(classification_report(y_train_ros, y_train_pred_knn))

# 📙 Testing Results
print("\n📙 Testing Data - KNN")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_knn))
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_knn))
# Out:
# 📘 Training Data - KNN
# Confusion Matrix:
# [[118   0]
#  [ 10 108]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       118
#            1       1.00      0.92      0.96       118
#
#     accuracy                           0.96       236
#    macro avg       0.96      0.96      0.96       236
# weighted avg       0.96      0.96      0.96       236
#
#
# 📙 Testing Data - KNN
# Confusion Matrix:
# [[10  0]
#  [ 3 26]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       1.00      0.90      0.95        29
#
#     accuracy                           0.92        39
#    macro avg       0.88      0.95      0.91        39
# weighted avg       0.94      0.92      0.93        39

# %%
from sklearn.metrics import roc_curve, auc

# %%
def plot_roc(model, x_test, y_test):
    probabilities = model.predict_proba(np.array(x_test))
    predictions = probabilities
    fpr, tpr, threshold = roc_curve(y_test, predictions[:,1])
    roc_auc = auc(fpr, tpr)

    plt.title("Reciever Operating Characterstics")
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0,1], [0,1], 'r--')
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Train the model
classifier3 = RandomForestClassifier(criterion='gini', random_state=1)
classifier3.fit(x_train_pca, y_train_ros)

# Predict
y_pred3 = classifier3.predict(x_test_pca)

# Accuracy
accuracy_RFE = accuracy_score(y_test, y_pred4)

# Now plot ROC
plot_roc(classifier4, x_test_pca, y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# 🔹 Train the KNN Classifier
classifier_knn = KNeighborsClassifier()
classifier_knn.fit(x_train_pca, y_train_ros)

# 🔹 Predict and Accuracy
y_pred_knn = classifier_knn.predict(x_test_pca)
accuracy_knn = accuracy_score(y_test, y_pred_knn)

# 🔹 ROC Curve
plot_roc(classifier_knn, x_test_pca, y_test)
